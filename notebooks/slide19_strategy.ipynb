# %%
from market_engine import UdemyMarketEngine
engine = UdemyMarketEngine().preprocess_and_train()
result = engine.predict_course(title='Java Masterclass', subject='Business Finance', level='All Levels', price=19.99)
