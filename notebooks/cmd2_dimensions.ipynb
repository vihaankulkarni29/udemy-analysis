# %% [markdown]
# # Command 2: Dataset Dimensions
#
# Check total rows, columns, and column names

# %%
print('Total Courses:', len(df))
print('Total Columns:', len(df.columns))
print('\nColumns:', list(df.columns))
