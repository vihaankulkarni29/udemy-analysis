# %% [markdown]
# # Command 6: Remove Duplicates
#
# Drops duplicate rows and shows new dataset shape

# %%
import pandas as pd
df = pd.read_csv('udemy_courses.csv')
df = df.drop_duplicates()
print(df.shape)
