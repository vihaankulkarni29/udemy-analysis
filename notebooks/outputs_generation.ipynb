# %% [markdown]
# # Output Visualizations - Code Reference
#
# Quick reference for how each visualization in the `outputs/` folder was generated.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Subject Distribution (subject_counts.png)

# %%
df['subject'].value_counts().plot(kind='bar')
plt.savefig('outputs/subject_counts.png')

# %% [markdown]
# ## 2. Price Distribution (price_distribution.png)

# %%
df['price'].hist(bins=30)
plt.savefig('outputs/price_distribution.png')

# %% [markdown]
# ## 3. Reviews vs Subscribers (reviews_vs_subscribers.png)

# %%
plt.scatter(df['num_subscribers'], df['num_reviews'], alpha=0.5)
plt.savefig('outputs/reviews_vs_subscribers.png')

# %% [markdown]
# ## 4. Correlation Heatmap (correlation_heatmap.png)

# %%
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.savefig('outputs/correlation_heatmap.png')

# %% [markdown]
# ---
#
# **Note**: All visualizations were generated during the execution of `udemy_analysis.py` which performs comprehensive EDA and ML modeling on the Udemy courses dataset.
